# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseObed-jesse/My-Website/blob/main/open_cv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# main .py 



#import modules here 
import cv2
import time
import PoseModule as pm # here the pm is the file made before 


cap = cv2.VideoCapture(0)#using camera 0 for thr first 1 for the second camera 
pTime = 0
detector = pm.poseDetector()#the module we made 
while True:
    success, img = cap.read()# if success then only we should run this code or quit 
    img = detector.findPose(img)
    lmList = detector.findPosition(img, draw=False)
    if len(lmList) !=0:
        print(lmList[14])
        cv2.circle(img, (lmList[14][1], lmList[14][2]), 15, (0, 0, 255), cv2.FILLED)
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    cv2.putText(img, str(int(fps)), (70, 50), cv2.FONT_HERSHEY_PLAIN, 3,
                (255, 0, 0), 3)
cv2.imshow("", img)#is true show or quit 
cv2.waitKey(1)

# %%
import cv2
import mediapipe as mp
import time
import math
class poseDetector():
    def __init__(self, mode=False, upBody=False, smooth=True,
                 detectionCon=0.5, trackCon=0.5):
        self.mode = mode
        self.upBody = upBody
        self.smooth = smooth
        self.detectionCon = detectionCon
        self.trackCon = trackCon
        self.mpDraw = mp.solutions.drawing_utils
        self.mpPose = mp.solutions.pose
        self.pose = self.mpPose.Pose(self.mode, self.upBody, self.smooth,
                                     self.detectionCon, self.trackCon)
    def findPose(self, img, draw=True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.pose.process(imgRGB)
        if self.results.pose_landmarks:
            if draw:
                self.mpDraw.draw_landmarks(img, self.results.pose_landmarks,
                                           self.mpPose.POSE_CONNECTIONS)
        return img
    def findPosition(self, img, draw=True):
        self.lmList = []
        if self.results.pose_landmarks:
            for id, lm in enumerate(self.results.pose_landmarks.landmark):
                h, w, c = img.shape
                # print(id, lm)
                cx, cy = int(lm.x * w), int(lm.y * h)
                self.lmList.append([id, cx, cy])
                if draw:
                    cv2.circle(img, (cx, cy), 5, (255, 0, 0), cv2.FILLED)
        return self.lmList
    def findAngle(self, img, p1, p2, p3, draw=True):
        # Get the landmarks
        x1, y1 = self.lmList[p1][1:]
        x2, y2 = self.lmList[p2][1:]
        x3, y3 = self.lmList[p3][1:]
        # Calculate the Angle
        angle = math.degrees(math.atan2(y3 - y2, x3 - x2) -
                             math.atan2(y1 - y2, x1 - x2))
        if angle < 0:
            angle += 360
        # print(angle)
        # Draw
        if draw:
            cv2.line(img, (x1, y1), (x2, y2), (255, 255, 255), 3)
            cv2.line(img, (x3, y3), (x2, y2), (255, 255, 255), 3)
            cv2.circle(img, (x1, y1), 10, (0, 0, 255), cv2.FILLED)
            cv2.circle(img, (x1, y1), 15, (0, 0, 255), 2)
            cv2.circle(img, (x2, y2), 10, (0, 0, 255), cv2.FILLED)
            cv2.circle(img, (x2, y2), 15, (0, 0, 255), 2)
            cv2.circle(img, (x3, y3), 10, (0, 0, 255), cv2.FILLED)
            cv2.circle(img, (x3, y3), 15, (0, 0, 255), 2)
            cv2.putText(img, str(int(angle)), (x2 - 50, y2 + 50),
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
        return angle
def main():
    cap = cv2.VideoCapture(0)
    pTime = 0
    detector = poseDetector()
    while True:
        success, img = cap.read()
        img = detector.findPose(img)
        lmList = detector.findPosition(img, draw=False)
        if len(lmList) != 0:
            print(lmList[14])
            cv2.circle(img, (lmList[14][1], lmList[14][2]), 15, (0, 0, 255), cv2.FILLED)
        cTime = time.time()
        fps = 1 / (cTime - pTime)
        pTime = cTime
        cv2.putText(img, str(int(fps)), (70, 50), cv2.FONT_HERSHEY_PLAIN, 3,
                    (255, 0, 0), 3)
        cv2.imshow("Image", img)
        cv2.waitKey(1)
if __name__ == "__main__":
    main()

# %% [markdown]
# ```
# ```
#
#
# *Human Pose Module Recognition using medaipipe opencv2*
#
# first we need to undestand the concept of the proect what we need to make what we need to do
#
#
#
# #              Points
#
#
# * learn about the module and how to use it
# * made a duplicate module out of it
# * write the main code
# * allow user camer to the code
# * make a frame
# * traine the code add module what need to be used
# * give self to all the modules and class method by self they can import the module and excute without the permision of the user
# * make a def for the find pose
# * draw the line
# * give the points
# * import the duplicate module
# * give the cap
# * if that is true than only run it or else quit the programe and give can not acces the programe
# * then find the len and list it
# if the frame got success the run the self and find the pose and wait for a key to be pressed
# ```
# ```
#
# pose module.py
#
# first i will import modules like cv2 mediapipe time math and if need sleep
# then i will make a main class called pose dectector this wil find the body then will draw , and make pose out of th pose
#
# then i will create a function called findpose with the above self , img, and mensition the draw function as true because we need to draw it on the frame given
#
# next point  made a find position
#
# from the self and the frame and the img create a new function to create the draw line as every thing as a id we need to get id out of the code using i=for or if
#
# the draw it using the id make vairables from ig make the shape out of it then make a find angle by the angle we can fin wheather it is leg or hand because every human has a angle on which it can bend now it is the main point we need to draw what can the camera do withn the code now we will drae the hands legs and many more parts of the body now draw circles using the same code but use circle in place of the line
#
# next we need to make the main function give access to the vidoe camere and if it is true only run or else quit it becaue if it is false anf=d we run it it will giveus error give time put the text for the fram e and the module is ready now use the module to make tha main.py
#
# ```
# ```
# main.py
#
# import the above made module
# give acesses to the camera next detect the camera next make sure that the camera is working or not
# next make the while loop for the true function if it true only run or else quit every thing and give the error give colour of the line and circles give the frame and make a waitkey  1 complete code if we want to add any more thing we can add like frame name etc......
